# %% [markdown]
# <a href="https://colab.research.google.com/github/rianzulhaq/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/gambar/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)		#konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/gambar/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/gambar/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray')

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/gambar/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# simpan File image
# cv.imwrite('/content/drive/MyDrive/PCVK/gambar/mandrill2.tiff', img5)

# tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))		#ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
# perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=18)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices

pts = vertices.reshape((-1,1,2))		#nilai 2 untuk menunjukan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts

cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
img_rg = img.copy()
img_rg [:,:,0] = 0    #Blue channel di set 0
plt.imshow(img_rg)

# %%
img_gb = img.copy()
img_gb [:,:,2] = 0    #Red channel di set 0
plt.imshow(img_gb)

# %%
img_ssssb = img.copy()
img9 = cv.cvtColor(img_ssssb,cv.COLOR_BGR2RGB)
img9 [:,:,2] = 0
plt.imshow(img9)

# %%
img_sb = img.copy()
img10 = cv.cvtColor(img_sb,cv.COLOR_BGR2RGB)
img10 [:,:,0] = 0
plt.imshow(img10)

# %%
img_sc = img[10:100, 10:100]
imgcrp = cv.cvtColor(img_sc, cv.COLOR_BGR2RGB)
plt.imshow(imgcrp)

# %%
img_sc2 = img[5:30, :]
img_sc2 [:, :, 0] = 0
img_sc2 [:, :, 2] = 0
plt.imshow(img_sc2)

# %%
import random
blank=np.zeros(shape=(600,600,3),dtype=np.int32)
n = 0
while (n < 5):
  k1 = random.randint(0,559)
  k2 = random.randint(0,559)
  kotak = cv.rectangle(blank, pt1=(k1, k1), pt2=(k2, k2), color=(k1, k2, random.randint(0,255)),thickness=5)
  n+=1
  plt.imshow(kotak)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_sc5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img_sc5)

# %%
img_sc7 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_sc7,pt1=(500,250),pt2=(250,50),color=(255,255,255),thickness=3)
cv.circle(img_sc7,center=(400,170),radius=100,color=(255,0,0),thickness=3)
plt.imshow(img_sc7)

# %%
img_sc8 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_sc8,pt1=(100,600),pt2=(5,500),color=(0,0,255),thickness=3)
plt.imshow(img_sc8)
